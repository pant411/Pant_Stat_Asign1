# %%
import os
os.chdir(os.getcwd())
os.getcwd()
# Out:
# '/Users/pantchanit/Documents/Pant_Stat_Asign1'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
country = pd.read_excel('countries_regions.xlsx')
country.head()
# Out:
#      Country Name                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %%
sns.set(rc={'figure.figsize': (15, 8)})

# %% [markdown]
# # Infrastructure

# %% [markdown]
# Broadband

# %%
broadband1 = pd.read_excel('infrastructure/broadband.xlsx')
broadband1.replace({'..':np.nan},inplace=True)
broadband1
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 11/23/2021          NaN
#
#                                         Series Name     Series Code  \
# 0    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# ...

# %%
broadband1 = country.join(broadband1[['2004 [YR2004]','2014 [YR2014]']])
broadband1
# Out:
#               Country Name                 Region  ThirdWorld  2004 [YR2004]  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
#      2014 [YR2014]
# 0         0.004495
# ...

# %%
sns.heatmap(broadband1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
DataCorre = country.join(broadband1[['2004 [YR2004]', '2014 [YR2014]']])
DataCorre
# Out:
#               Country Name                 Region  ThirdWorld  2004 [YR2004]  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
#      2014 [YR2014]
# 0         0.004495
# ...

# %%
DataCorre.rename(columns={'2004 [YR2004]':'Broadband2004','2014 [YR2014]':'Broadband2014'}, inplace=True)
DataCorre
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
#      Broadband2014
# 0         0.004495
# ...

# %% [markdown]
# electricity

# %%
electricity1 = pd.read_excel('infrastructure/electricity.xlsx')
electricity1.replace({'..':np.nan},inplace=True)
electricity1
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 11/23/2021          NaN
#
#                                      Series Name        Series Code  \
# 0    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# ...

# %%
electricity1 = country.join(electricity1[['2004 [YR2004]', '2014 [YR2014]']])
electricity1
# Out:
#               Country Name                 Region  ThirdWorld  2004 [YR2004]  \
# 0              Afghanistan             South Asia           1            NaN
# 1                  Albania         Eastern Europe           0    1797.525487
# 2                  Algeria                 Africa           0     804.107334
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0            NaN
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0            NaN
# 213     West Bank and Gaza            Middle East           0            NaN
# 214            Yemen, Rep.            Middle East           1     173.387070
# 215                 Zambia                 Africa           1     685.156780
# 216               Zimbabwe                 Africa           0     855.746769
#
#      2014 [YR2014]
# 0              NaN
# ...

# %%
sns.heatmap(electricity1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
DataCorre2 = DataCorre.join(electricity1[['2004 [YR2004]','2014 [YR2014]']])
DataCorre2
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
# ...

# %%
DataCorre2.rename(columns={'2004 [YR2004]':'Electricity2004','2014 [YR2014]':'Electricity2014'}, inplace=True)
DataCorre2
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
# ...

# %% [markdown]
# mobile

# %%
mobile1 = pd.read_excel('infrastructure/mobile.xlsx')
mobile1.replace({'..':np.nan},inplace=True)
mobile1
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 11/23/2021          NaN
#
#                                         Series Name     Series Code  \
# 0    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# ...

# %%
mobile1 = country.join(mobile1[['2004 [YR2004]', '2014 [YR2014]']])
mobile1
# Out:
#               Country Name                 Region  ThirdWorld  2004 [YR2004]  \
# 0              Afghanistan             South Asia           1       2.426528
# 1                  Albania         Eastern Europe           0      40.567917
# 2                  Algeria                 Africa           0      14.934509
# 3           American Samoa  Australia and Oceanea           0       3.770044
# 4                  Andorra         Western Europe           0      76.551597
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0      59.393850
# 213     West Bank and Gaza            Middle East           0      12.456142
# 214            Yemen, Rep.            Middle East           1       7.553698
# 215                 Zambia                 Africa           1       4.020157
# 216               Zimbabwe                 Africa           0       3.541998
#
#      2014 [YR2014]
# 0        55.159515
# ...

# %%
sns.heatmap(mobile1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
DataCorre3 = DataCorre2.join(mobile1[['2004 [YR2004]','2014 [YR2014]']])
DataCorre3
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
# ...

# %%
DataCorre3.rename(columns={'2004 [YR2004]':'Mobile2004','2014 [YR2014]':'Mobile2014'}, inplace=True)
DataCorre3
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
# ...

# %% [markdown]
# # Health

# %% [markdown]
# life_expectancy

# %%
life_expectancy1 = pd.read_excel('health/life_expectancy.xlsx')
life_expectancy1.replace({'..':np.nan},inplace=True)
life_expectancy1
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 11/23/2021          NaN
#
#                                  Series Name     Series Code  1990 [YR1990]  \
# 0    Life expectancy at birth, total (years)  SP.DYN.LE00.IN         50.331
# ...

# %%
life_expectancy1 = country.join(
    life_expectancy1[['2004 [YR2004]', '2014 [YR2014]']])
life_expectancy1
# Out:
#               Country Name                 Region  ThirdWorld  2004 [YR2004]  \
# 0              Afghanistan             South Asia           1      57.772000
# 1                  Albania         Eastern Europe           0      75.039000
# 2                  Algeria                 Africa           0      72.594000
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0            NaN
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0      77.773171
# 213     West Bank and Gaza            Middle East           0      71.842000
# 214            Yemen, Rep.            Middle East           1      62.931000
# 215                 Zambia                 Africa           1      47.354000
# 216               Zimbabwe                 Africa           0      43.065000
#
#      2014 [YR2014]
# 0        62.966000
# ...

# %%
sns.heatmap(life_expectancy1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
DataCorre4 = DataCorre3.join(
    life_expectancy1[['2004 [YR2004]', '2014 [YR2014]']])
DataCorre4
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
# ...

# %%
DataCorre4.rename(columns={'2004 [YR2004]':'Life_expectancy2004','2014 [YR2014]':'Life_expectancy2014'}, inplace=True)
DataCorre4
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
# ...

# %% [markdown]
# mortality_infant_rate

# %%
mortality_infant_rate1 = pd.read_excel('health/mortality_infant_rate.xlsx')
mortality_infant_rate1.replace({'..':np.nan},inplace=True)
mortality_infant_rate1
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 11/23/2021          NaN
#
#                                         Series Name     Series Code  \
# 0    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN
# ...

# %%
mortality_infant_rate1 = country.join(
    mortality_infant_rate1[['2004 [YR2004]', '2014 [YR2014]']])
mortality_infant_rate1
# Out:
#               Country Name                 Region  ThirdWorld  2004 [YR2004]  \
# 0              Afghanistan             South Asia           1           79.6
# 1                  Albania         Eastern Europe           0           19.1
# 2                  Algeria                 Africa           0           30.1
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0            5.6
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0            NaN
# 213     West Bank and Gaza            Middle East           0           22.6
# 214            Yemen, Rep.            Middle East           1           57.0
# 215                 Zambia                 Africa           1           68.8
# 216               Zimbabwe                 Africa           0           52.0
#
#      2014 [YR2014]
# 0             55.2
# ...

# %%
sns.heatmap(mortality_infant_rate1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
DataCorre5 = DataCorre4.join(mortality_infant_rate1[['2004 [YR2004]','2014 [YR2014]']])
DataCorre5
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
# ...

# %%
DataCorre5.rename(columns={'2004 [YR2004]':'Mortality_infant_rate2004','2014 [YR2014]':'Mortality_infant_rate2014'}, inplace=True)
DataCorre5
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
# ...

# %% [markdown]
# physician

# %%
physician1 = pd.read_excel('health/physician.xlsx')
physician1.replace({'..':np.nan},inplace=True)
physician1
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 11/23/2021          NaN
#
#                        Series Name     Series Code  1990 [YR1990]  \
# 0    Physicians (per 1,000 people)  SH.MED.PHYS.ZS         0.1090
# ...

# %%
physician1 = country.join(physician1[['2004 [YR2004]', '2014 [YR2014]']])
physician1
# Out:
#               Country Name                 Region  ThirdWorld  2004 [YR2004]  \
# 0              Afghanistan             South Asia           1            NaN
# 1                  Albania         Eastern Europe           0         1.1913
# 2                  Algeria                 Africa           0            NaN
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0         3.1324
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0            NaN
# 213     West Bank and Gaza            Middle East           0            NaN
# 214            Yemen, Rep.            Middle East           1         0.3449
# 215                 Zambia                 Africa           1         0.1298
# 216               Zimbabwe                 Africa           0         0.1735
#
#      2014 [YR2014]
# 0           0.2983
# ...

# %%
sns.heatmap(physician1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
DataCorre6 = DataCorre5.join(physician1[['2004 [YR2004]','2014 [YR2014]']])
DataCorre6
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
# ...

# %%
DataCorre6.rename(columns={'2004 [YR2004]':'Physician2004','2014 [YR2014]':'Physician2014'}, inplace=True)
DataCorre6
# Out:
#               Country Name                 Region  ThirdWorld  Broadband2004  \
# 0              Afghanistan             South Asia           1       0.000809
# 1                  Albania         Eastern Europe           0            NaN
# 2                  Algeria                 Africa           0       0.110118
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0       8.239337
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0       1.372905
# 213     West Bank and Gaza            Middle East           0       0.000514
# 214            Yemen, Rep.            Middle East           1            NaN
# 215                 Zambia                 Africa           1       0.002164
# 216               Zimbabwe                 Africa           0       0.074601
#
# ...

# %%
DataCorre6 = DataCorre6.dropna()
DataCorre6
# Out:
#              Country Name           Region  ThirdWorld  Broadband2004  \
# 8                 Armenia     Western Asia           0       0.033325
# 11                Austria   Western Europe           0      10.588057
# 14                Bahrain      Middle East           0       1.802266
# 17                Belarus   Eastern Europe           0       0.007799
# 18                Belgium   Western Europe           0      15.457308
# ..                    ...              ...         ...            ...
# 204  United Arab Emirates      Middle East           0       1.379993
# 205        United Kingdom  Northern Europe           0      10.228203
# 206         United States    North America           0      12.776441
# 208            Uzbekistan     Western Asia           0       0.021145
# 216              Zimbabwe           Africa           0       0.074601
#
#      Broadband2014  Electricity2004  Electricity2014  Mobile2004  Mobile2014  \
# ...

# %%
DataCorre6 = DataCorre6[(DataCorre6.Region != "Thailand")&(DataCorre6.Region != "Australia and Oceanea")]
#DataCorre6 = DataCorre6[DataCorre6.Region != "Australia and Oceanea"]
DataCorre6
# Out:
#              Country Name           Region  ThirdWorld  Broadband2004  \
# 8                 Armenia     Western Asia           0       0.033325
# 11                Austria   Western Europe           0      10.588057
# 14                Bahrain      Middle East           0       1.802266
# 17                Belarus   Eastern Europe           0       0.007799
# 18                Belgium   Western Europe           0      15.457308
# ..                    ...              ...         ...            ...
# 204  United Arab Emirates      Middle East           0       1.379993
# 205        United Kingdom  Northern Europe           0      10.228203
# 206         United States    North America           0      12.776441
# 208            Uzbekistan     Western Asia           0       0.021145
# 216              Zimbabwe           Africa           0       0.074601
#
#      Broadband2014  Electricity2004  Electricity2014  Mobile2004  Mobile2014  \
# ...

# %%
sns.pairplot(DataCorre6)

# %% [markdown]
# Correlation Table

# %%
sns.heatmap(DataCorre6.corr(),
            square=True,
            linewidths=0.2,    
            linecolor=(0,0,0),
            cmap=sns.color_palette("coolwarm"),
            annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Pairplot Table

# %%
sns.pairplot(DataCorre6,hue='ThirdWorld', markers=["o", "D"])

# %%
DataCorre6.keys()
# Out:
# Index(['Country Name', 'Region', 'ThirdWorld', 'Broadband2004',
#        'Broadband2014', 'Electricity2004', 'Electricity2014', 'Mobile2004',
#        'Mobile2014', 'Life_expectancy2004', 'Life_expectancy2014',
#        'Mortality_infant_rate2004', 'Mortality_infant_rate2014',
#        'Physician2004', 'Physician2014'],
#       dtype='object')

# %% [markdown]
# Broadband2004 vs Life_expectancy2004,Mortality_infant_rate2004,Physician2004

# %%
sns.pairplot(DataCorre6, vars=['Broadband2004', 'Life_expectancy2004',
             'Mortality_infant_rate2004', 'Physician2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Electricity2004 vs Life_expectancy2004, Mortality_infant_rate2004, Physician2004

# %%
sns.pairplot(DataCorre6, vars=[
             'Electricity2004', 'Life_expectancy2004', 'Mortality_infant_rate2004', 'Physician2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Mobile2004 vs Life_expectancy2004, Mortality_infant_rate2004, Physician2004

# %%
sns.pairplot(DataCorre6, vars=[
             'Mobile2004', 'Life_expectancy2004', 'Mortality_infant_rate2004', 'Physician2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Broadband2014 vs Life_expectancy2014, Mortality_infant_rate2014, Physician2014

# %%
sns.pairplot(DataCorre6, vars=['Broadband2014', 'Life_expectancy2014',
             'Mortality_infant_rate2014', 'Physician2014'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Electricity2014 vs Life_expectancy2014, Mortality_infant_rate2014, Physician2014

# %%
sns.pairplot(DataCorre6, vars=[
             'Electricity2014', 'Life_expectancy2014', 'Mortality_infant_rate2014', 'Physician2014'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Mobile2014 vs Life_expectancy2014, Mortality_infant_rate2014, Physician2014

# %%
sns.pairplot(DataCorre6, vars=[
             'Mobile2014', 'Life_expectancy2014', 'Mortality_infant_rate2014', 'Physician2014'], hue='ThirdWorld', markers=["o", "D"])

# %%
# to csv file
#DataCorre6.to_csv('inftra_health_2004_2014.csv',index=False) ขออนุญาตคอมเมนต์นะครับกลัวทับไฟล์ที่ทำไว้ตอนแรก

# %% [markdown]
# Broadband2004 vs Life_expectancy2004

# %%
sns.pairplot(DataCorre6, vars=['Broadband2004', 'Life_expectancy2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Broadband2004 vs Mortality_infant_rate2004

# %%
sns.pairplot(DataCorre6, vars=['Broadband2004','Mortality_infant_rate2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Broadband2004 vs Physician2004

# %%
sns.pairplot(DataCorre6, vars=['Broadband2004','Physician2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Electricity2004 vs Life_expectancy2004

# %%
sns.pairplot(DataCorre6, vars=['Electricity2004', 'Life_expectancy2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Electricity2004 vs Mortality_infant_rate2004

# %%
sns.pairplot(DataCorre6, vars=['Electricity2004', 'Mortality_infant_rate2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Electricity2004 vs Physician2004

# %%
sns.pairplot(DataCorre6, vars=['Electricity2004', 'Physician2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Mobile2004 vs Life_expectancy2004

# %%
sns.pairplot(DataCorre6, vars=['Mobile2004', 'Life_expectancy2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Mobile2004 vs Mortality_infant_rate2004

# %%
sns.pairplot(DataCorre6, vars=['Mobile2004', 'Mortality_infant_rate2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Mobile2004 vs Physician2004

# %%
sns.pairplot(DataCorre6, vars=['Mobile2004', 'Physician2004'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Broadband2014 vs Life_expectancy2014

# %%
sns.pairplot(DataCorre6, vars=['Broadband2014', 'Life_expectancy2014'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Broadband2014 vs Mortality_infant_rate2014

# %%
sns.pairplot(DataCorre6, vars=['Broadband2014', 'Mortality_infant_rate2014'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Broadband2014 vs Physician2014

# %%
sns.pairplot(DataCorre6, vars=['Broadband2014', 'Physician2014'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Electricity2014 vs Life_expectancy2014

# %%
sns.pairplot(DataCorre6, vars=['Electricity2014', 'Life_expectancy2014'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Electricity2014 vs Mortality_infant_rate2014

# %%
sns.pairplot(DataCorre6, vars=['Electricity2014', 'Mortality_infant_rate2014'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Electricity2014 vs Physician2014

# %%
sns.pairplot(DataCorre6, vars=['Electricity2014', 'Physician2014'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Mobile2014 vs Life_expectancy2014

# %%
sns.pairplot(DataCorre6, vars=['Mobile2014', 'Life_expectancy2014'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Mobile2014 vs Mortality_infant_rate2014

# %%
sns.pairplot(DataCorre6, vars=['Mobile2014', 'Mortality_infant_rate2014'], hue='ThirdWorld', markers=["o", "D"])

# %% [markdown]
# Mobile2014 vs Physician2014

# %%
sns.pairplot(DataCorre6, vars=['Mobile2014', 'Physician2014'], hue='ThirdWorld', markers=["o", "D"])
