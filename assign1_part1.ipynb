# %%
import os
os.chdir(os.getcwd())
os.getcwd()
# Out:
# '/Users/pantchanit/Documents/Pant_Stat_Asign1'

# %%
import pandas as pd
import numpy as np
import matplotlib as mpe
import seaborn as sns
# %matplotlib inline

# %%
country = pd.read_excel('countries_regions.xlsx')
country.head()
# Out:
#      Country Name                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %% [markdown]
# # GET DATA Broadband

# %%
broadband1 = pd.read_excel('infrastructure/broadband.xlsx')
broadband1.replace({'..':np.nan},inplace=True)
broadband1
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 11/23/2021          NaN
#
#                                         Series Name     Series Code  \
# 0    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 1    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 2    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 3    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 4    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# ..                                              ...             ...
# 217                                             NaN             NaN
# 218                                             NaN             NaN
# 219                                             NaN             NaN
# 220                                             NaN             NaN
# 221                                             NaN             NaN
#
#      1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 2              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
#      1994 [YR1994]  1995 [YR1995]  ...  2011 [YR2011]  2012 [YR2012]  \
# 0              NaN            NaN  ...            NaN       0.004814
# 1              NaN            NaN  ...       4.377872       5.493573
# 2              NaN            NaN  ...       2.675159       3.088892
# 3              NaN            NaN  ...            NaN            NaN
# 4              NaN            NaN  ...      30.762893      32.641004
# ..             ...            ...  ...            ...            ...
# 217            NaN            NaN  ...            NaN            NaN
# 218            NaN            NaN  ...            NaN            NaN
# 219            NaN            NaN  ...            NaN            NaN
# 220            NaN            NaN  ...            NaN            NaN
# 221            NaN            NaN  ...            NaN            NaN
#
#      2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0         0.004648       0.004495       0.020535       0.024874
# 1         6.286818       7.180321       8.402315       9.228641
# 2         3.356045       4.109816       5.712209       7.051711
# 3              NaN            NaN            NaN            NaN
# 4        34.335306      36.319796      39.345733      42.032679
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
#      2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]
# 0         0.025297       0.043041       0.051741       0.068254
# 1        10.526845      12.555659      15.140735      17.684951
# 2         7.756294       7.262935       8.321684       8.643942
# 3              NaN            NaN            NaN            NaN
# 4        44.524097      46.311976      47.131264            NaN
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
# [222 rows x 35 columns]

# %%
broadband1.keys()
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
#        '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
#        '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
#        '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]'],
#       dtype='object')

# %%
broadband1 = country.join(broadband1[['Country Code', 'Series Name', 'Series Code',
       '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
       '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
       '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
       '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
       '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
       '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
       '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
       '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]']])
broadband1
# Out:
#               Country Name                 Region  ThirdWorld Country Code  \
# 0              Afghanistan             South Asia           1          AFG
# 1                  Albania         Eastern Europe           0          ALB
# 2                  Algeria                 Africa           0          DZA
# 3           American Samoa  Australia and Oceanea           0          ASM
# 4                  Andorra         Western Europe           0          AND
# ..                     ...                    ...         ...          ...
# 212  Virgin Islands (U.S.)          North America           0          VIR
# 213     West Bank and Gaza            Middle East           0          PSE
# 214            Yemen, Rep.            Middle East           1          YEM
# 215                 Zambia                 Africa           1          ZMB
# 216               Zimbabwe                 Africa           0          ZWE
#
#                                         Series Name     Series Code  \
# 0    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 1    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 2    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 3    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 4    Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# ..                                              ...             ...
# 212  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 213  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 214  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 215  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 216  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
#
#      1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  ...  \
# 0              NaN            NaN            NaN            NaN  ...
# 1              NaN            NaN            NaN            NaN  ...
# 2              NaN            NaN            NaN            NaN  ...
# 3              NaN            NaN            NaN            NaN  ...
# 4              NaN            NaN            NaN            NaN  ...
# ..             ...            ...            ...            ...  ...
# 212            NaN            NaN            NaN            NaN  ...
# 213            NaN            NaN            NaN            NaN  ...
# 214            NaN            NaN            NaN            NaN  ...
# 215            NaN            NaN            NaN            NaN  ...
# 216            NaN            NaN            NaN            NaN  ...
#
#      2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# 0              NaN       0.004814       0.004648       0.004495
# 1         4.377872       5.493573       6.286818       7.180321
# 2         2.675159       3.088892       3.356045       4.109816
# 3              NaN            NaN            NaN            NaN
# 4        30.762893      32.641004      34.335306      36.319796
# ..             ...            ...            ...            ...
# 212            NaN            NaN       8.641729       8.657267
# 213       3.758487       4.394125       4.916669       5.309577
# 214       0.457837       0.683606       1.021191       1.316631
# 215       0.117056       0.103691       0.090088       0.133255
# 216       0.263682       0.548259       0.778375       1.120463
#
#      2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 0         0.020535       0.024874       0.025297       0.043041
# 1         8.402315       9.228641      10.526845      12.555659
# 2         5.712209       7.051711       7.756294       7.262935
# 3              NaN            NaN            NaN            NaN
# 4        39.345733      42.032679      44.524097      46.311976
# ..             ...            ...            ...            ...
# 212       8.574859            NaN            NaN            NaN
# 213       6.060718       6.917773       7.580678       7.486892
# 214       1.490685       1.016699       1.325692       1.355607
# 215       0.147298       0.194238       0.213082       0.416259
# 216       1.187053       1.217633       1.315694       1.406322
#
#      2019 [YR2019]  2020 [YR2020]
# 0         0.051741       0.068254
# 1        15.140735      17.684951
# 2         8.321684       8.643942
# 3              NaN            NaN
# 4        47.131264            NaN
# ..             ...            ...
# 212            NaN            NaN
# 213       7.324839       7.312678
# 214            NaN            NaN
# 215       0.497681       0.447765
# 216       1.395817       1.368916
#
# [217 rows x 37 columns]

# %%
broadband1 = broadband1[broadband1.Region != "Thailand"]
broadband1 = broadband1[broadband1.Region != "Australia and Oceanea"]

# %%
sns.heatmap(broadband1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#broadband1.drop(['1990 [YR1990]','1991 [YR1991]','1992 [YR1992]','1993 [YR1993]','1994 [YR1994]','1995 [YR1995]','1996 [YR1996]','1997 [YR1997]'],axis=1, inplace=True)
broadband1 = broadband1.dropna()
broadband1
# Out:
#              Country Name          Region  ThirdWorld Country Code  \
# 18                Belgium  Western Europe           0          BEL
# 26                 Brazil   South America           0          BRA
# 35                 Canada   North America           0          CAN
# 68                 France  Western Europe           0          FRA
# 86   Hong Kong SAR, China       East Asia           0          HKG
# 98                  Japan       East Asia           0          JPN
# 104           Korea, Rep.       East Asia           0          KOR
# 171             Singapore  Southeast Asia           0          SGP
# 206         United States   North America           0          USA
#
#                                         Series Name     Series Code  \
# 18   Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 26   Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 35   Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 68   Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 86   Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 98   Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 104  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 171  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 206  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
#
#      1998 [YR1998]  1999 [YR1999]  2000 [YR2000]  2001 [YR2001]  ...  \
# 18        0.106708       0.224277       1.402592       4.457895  ...
# 26        0.000589       0.004062       0.057211       0.186799  ...
# 35        0.466324       1.920633       4.612640       9.183916  ...
# 68        0.023037       0.093690       0.333137       1.012897  ...
# 86        0.171420       1.325680       6.727642      10.749580  ...
# 98        0.025174       0.169643       0.670191       3.002807  ...
# 104       0.030030       0.591276       8.168134      16.387841  ...
# 171       0.259019       0.758583       1.712639       3.703572  ...
# 206       0.256527       0.988801       2.509620       4.494889  ...
#
#      2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# 18       32.175470      33.305275      34.327729      35.746533
# 26        9.028728       9.594011      10.625283      11.820828
# 35       32.666050      33.474326      34.265299      35.239685
# 68       35.982598      37.725626      39.033689      40.454220
# 86       32.811967      32.000676      31.531852      31.974499
# 98       27.779379      28.135337      28.772070      29.483756
# 104      35.872464      36.461103      37.217692      37.936629
# 171      26.753370      26.684168      27.383059      26.675711
# 206      28.344519      29.458940      30.351402      30.692865
#
#      2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 18       36.508424      37.609222      38.345618      39.216863
# 26       12.462590      13.028900      13.909125      14.910538
# 35       36.404624      36.793328      37.906373      38.963659
# 68       41.684509      42.803509      43.921804      44.775767
# 86       32.672339      36.253369      36.380384      36.825535
# 98       30.372730      31.155736      31.789490      32.622310
# 104      39.400237      40.318339      41.482202      41.596929
# 171      26.576531      28.157111      25.853003      25.941820
# 206      31.853820      32.727172      33.283628      33.860368
#
#      2019 [YR2019]  2020 [YR2020]
# 18       39.783140      40.848697
# 26       15.592074      17.098593
# 35       40.826166      41.801011
# 68       45.693420      46.921024
# 86       37.718288      38.296496
# 98       33.503380      34.499103
# 104      42.764354      43.554782
# 171      25.911659      25.940364
# 206      34.725367      36.413908
#
# [9 rows x 29 columns]

# %%
#broadband with outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=broadband1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_broadband2000_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(x="Region",y="2018 [YR2018]",data=broadband1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_broadband2014_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
#broadband without outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=broadband1, showfliers = False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_broadband2000_without_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(x="Region",y="2018 [YR2018]",data=broadband1, showfliers = False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_broadband2014_without_outliers.jpg', orientation="horizontal", dpi = 300)

# %% [markdown]
# # GET DATA Electricity

# %%
electricity1 = pd.read_excel('infrastructure/electricity.xlsx')
electricity1.replace({'..':np.nan},inplace=True)
electricity1
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 11/23/2021          NaN
#
#                                      Series Name        Series Code  \
# 0    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 1    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 2    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 3    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 4    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# ..                                           ...                ...
# 217                                          NaN                NaN
# 218                                          NaN                NaN
# 219                                          NaN                NaN
# 220                                          NaN                NaN
# 221                                          NaN                NaN
#
#      1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  \
# 0              NaN            NaN            NaN            NaN
# 1       552.252185     418.453589     453.644074     536.363825
# 2       531.583836     532.490560     559.783013     547.990472
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
#      1994 [YR1994]  1995 [YR1995]  ...  2011 [YR2011]  2012 [YR2012]  \
# 0              NaN            NaN  ...            NaN            NaN
# 1       596.407959     663.783995  ...    2205.703920    2118.327776
# 2       550.971960     559.917891  ...    1123.332915    1237.966109
# 3              NaN            NaN  ...            NaN            NaN
# 4              NaN            NaN  ...            NaN            NaN
# ..             ...            ...  ...            ...            ...
# 217            NaN            NaN  ...            NaN            NaN
# 218            NaN            NaN  ...            NaN            NaN
# 219            NaN            NaN  ...            NaN            NaN
# 220            NaN            NaN  ...            NaN            NaN
# 221            NaN            NaN  ...            NaN            NaN
#
#      2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0              NaN            NaN            NaN            NaN
# 1      2533.252829    2309.366503            NaN            NaN
# 2      1278.915242    1362.871884            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
#      2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 2              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
# [222 rows x 35 columns]

# %%
electricity1.keys()
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
#        '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
#        '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
#        '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]'],
#       dtype='object')

# %%
electricity1 = country.join(electricity1[['Country Code', 'Series Name', 'Series Code',
       '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
       '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
       '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
       '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
       '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
       '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
       '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
       '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]']])
electricity1
# Out:
#               Country Name                 Region  ThirdWorld Country Code  \
# 0              Afghanistan             South Asia           1          AFG
# 1                  Albania         Eastern Europe           0          ALB
# 2                  Algeria                 Africa           0          DZA
# 3           American Samoa  Australia and Oceanea           0          ASM
# 4                  Andorra         Western Europe           0          AND
# ..                     ...                    ...         ...          ...
# 212  Virgin Islands (U.S.)          North America           0          VIR
# 213     West Bank and Gaza            Middle East           0          PSE
# 214            Yemen, Rep.            Middle East           1          YEM
# 215                 Zambia                 Africa           1          ZMB
# 216               Zimbabwe                 Africa           0          ZWE
#
#                                      Series Name        Series Code  \
# 0    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 1    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 2    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 3    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 4    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# ..                                           ...                ...
# 212  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 213  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 214  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 215  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 216  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
#
#      1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  ...  \
# 0              NaN            NaN            NaN            NaN  ...
# 1       552.252185     418.453589     453.644074     536.363825  ...
# 2       531.583836     532.490560     559.783013     547.990472  ...
# 3              NaN            NaN            NaN            NaN  ...
# 4              NaN            NaN            NaN            NaN  ...
# ..             ...            ...            ...            ...  ...
# 212            NaN            NaN            NaN            NaN  ...
# 213            NaN            NaN            NaN            NaN  ...
# 214     125.619268     133.310280     134.242622     136.569517  ...
# 215     761.865751     736.782955     735.740792     740.600918  ...
# 216     865.380182     856.098975     787.210801     737.236625  ...
#
#      2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# 0              NaN            NaN            NaN            NaN
# 1      2205.703920    2118.327776    2533.252829    2309.366503
# 2      1123.332915    1237.966109    1278.915242    1362.871884
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 212            NaN            NaN            NaN            NaN
# 213            NaN            NaN            NaN            NaN
# 214     193.803773     193.804024     250.963212     219.799897
# 215     631.738878     733.210611     747.058044     717.347305
# 216     636.248991     608.761669     628.746242     609.124652
#
#      2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 2              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 212            NaN            NaN            NaN            NaN
# 213            NaN            NaN            NaN            NaN
# 214            NaN            NaN            NaN            NaN
# 215            NaN            NaN            NaN            NaN
# 216            NaN            NaN            NaN            NaN
#
#      2019 [YR2019]  2020 [YR2020]
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# ..             ...            ...
# 212            NaN            NaN
# 213            NaN            NaN
# 214            NaN            NaN
# 215            NaN            NaN
# 216            NaN            NaN
#
# [217 rows x 37 columns]

# %%
electricity1 = electricity1[electricity1.Region != "Thailand"]
electricity1 = electricity1[electricity1.Region != "Australia and Oceanea"]

# %%
sns.heatmap(electricity1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
electricity1.drop(['2015 [YR2015]','2016 [YR2016]','2017 [YR2017]','2018 [YR2018]','2019 [YR2019]','2020 [YR2020]'],axis=1, inplace=True)
electricity1 = electricity1.dropna()
electricity1
# Out:
#       Country Name          Region  ThirdWorld Country Code  \
# 1          Albania  Eastern Europe           0          ALB
# 2          Algeria          Africa           0          DZA
# 5           Angola          Africa           1          AGO
# 7        Argentina   South America           0          ARG
# 8          Armenia    Western Asia           0          ARM
# ..             ...             ...         ...          ...
# 210  Venezuela, RB   South America           0          VEN
# 211        Vietnam  Southeast Asia           0          VNM
# 214    Yemen, Rep.     Middle East           1          YEM
# 215         Zambia          Africa           1          ZMB
# 216       Zimbabwe          Africa           0          ZWE
#
#                                      Series Name        Series Code  \
# 1    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 2    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 5    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 7    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 8    Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# ..                                           ...                ...
# 210  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 211  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 214  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 215  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 216  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
#
#      1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  ...  \
# 1       552.252185     418.453589     453.644074     536.363825  ...
# 2       531.583836     532.490560     559.783013     547.990472  ...
# 5        53.171804      54.453865      53.486663      52.007473  ...
# 7      1303.978019    1347.592046    1410.377544    1496.904499  ...
# 8      2722.598500    2689.680533    1962.635282    1195.024488  ...
# ..             ...            ...            ...            ...  ...
# 210    2477.656497    2549.522266    2689.309414    2697.686148  ...
# 211      95.250905      98.780252     101.843182     112.060380  ...
# 214     125.619268     133.310280     134.242622     136.569517  ...
# 215     761.865751     736.782955     735.740792     740.600918  ...
# 216     865.380182     856.098975     787.210801     737.236625  ...
#
#      2005 [YR2005]  2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  \
# 1      1722.072850    1218.360146    1213.124369    1617.744156
# 2       890.625924     862.429594     894.284586     947.291328
# 5       109.295219     144.715322     133.267258     172.384898
# 7      2408.432958    2374.097592    2455.656081    2772.843291
# 8      1521.503310    1639.792570    1773.161496    1669.409464
# ..             ...            ...            ...            ...
# 210    2886.490448    2999.308385    3019.164880    3125.254764
# 211     569.956850     645.208981     728.088269     802.553943
# 214     183.663580     193.883809     211.206251     230.128161
# 215     692.715163     704.562149     664.162833     589.561562
# 216     891.882938     871.951256     760.204048     627.890199
#
#      2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# 1      1835.684072    1943.343354    2205.703920    2118.327776
# 2       866.307302    1016.636782    1123.332915    1237.966109
# 5       189.257704     206.454402     207.013351     219.253483
# 7      2730.123367    2877.652653    2929.075029    3000.603523
# 8      1661.303268    1726.262758    1807.034572    1892.006869
# ..             ...            ...            ...            ...
# 210    3090.969608    3195.681623    3256.626059    3304.402836
# 211     906.154107    1022.432620    1102.807176    1206.310430
# 214     226.989460     254.849372     193.803773     193.804024
# 215     568.438841     590.548895     631.738878     733.210611
# 216     585.457099     606.643960     636.248991     608.761669
#
#      2013 [YR2013]  2014 [YR2014]
# 1      2533.252829    2309.366503
# 2      1278.915242    1362.871884
# 5       280.214482     312.228895
# 7      2967.376558    3074.702071
# 8      1931.258117    1961.610395
# ..             ...            ...
# 210    3299.011056    2719.138349
# 211    1276.856078    1423.699910
# 214     250.963212     219.799897
# 215     747.058044     717.347305
# 216     628.746242     609.124652
#
# [130 rows x 31 columns]

# %%
sns.heatmap(electricity1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#electricity with outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=electricity1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_electricity2000_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(x="Region",y="2014 [YR2014]",data=electricity1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_electricity2014_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
#electricity without outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=electricity1, showfliers = False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_electricity2000_without_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(
    x="Region", y="2014 [YR2014]", data=electricity1, showfliers=False)
chart.set_xticklabels(chart.get_xticklabels(),
                      rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_electricity2014_without_outliers.jpg', orientation="horizontal", dpi = 300)

# %% [markdown]
# # GET DATA Mobile

# %%
mobile1 = pd.read_excel('infrastructure/mobile.xlsx')
mobile1.replace({'..':np.nan},inplace=True)
mobile1
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 11/23/2021          NaN
#
#                                         Series Name     Series Code  \
# 0    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 1    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 2    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 3    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 4    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# ..                                              ...             ...
# 217                                             NaN             NaN
# 218                                             NaN             NaN
# 219                                             NaN             NaN
# 220                                             NaN             NaN
# 221                                             NaN             NaN
#
#      1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  \
# 0         0.000000        0.00000       0.000000       0.000000
# 1         0.000000        0.00000       0.000000       0.000000
# 2         0.001825        0.01811       0.017689       0.017300
# 3         0.000000        0.00000       1.402918       1.764014
# 4         0.000000        0.00000       1.307567       1.279297
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
#      1994 [YR1994]  1995 [YR1995]  ...  2011 [YR2011]  2012 [YR2012]  \
# 0         0.000000       0.000000  ...      45.813626      49.227977
# 1         0.000000       0.000000  ...     105.852915     120.105858
# 2         0.004778       0.016312  ...      97.148178     100.384679
# 3         2.303484       2.351348  ...            NaN            NaN
# 4         1.250858       4.424432  ...      77.667260      77.480680
# ..             ...            ...  ...            ...            ...
# 217            NaN            NaN  ...            NaN            NaN
# 218            NaN            NaN  ...            NaN            NaN
# 219            NaN            NaN  ...            NaN            NaN
# 220            NaN            NaN  ...            NaN            NaN
# 221            NaN            NaN  ...            NaN            NaN
#
#      2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0        52.083576      55.159515      57.271068      61.054638
# 1       126.936969     115.997935     117.659218     116.744444
# 2       103.610140     111.238610     108.808940     116.004208
# 3              NaN            NaN            NaN            NaN
# 4        79.147993      83.623900      91.443514      98.492826
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
#      2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]
# 0        65.929134      59.120848      59.356020      58.255812
# 1       125.710352      94.176998      91.293015      91.002944
# 2       110.767246     111.664792     105.510594     103.887317
# 3              NaN            NaN            NaN            NaN
# 4       104.332411     107.282549     113.957377            NaN
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
# [222 rows x 35 columns]

# %%
mobile1.keys()
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
#        '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
#        '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
#        '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]'],
#       dtype='object')

# %%
mobile1 = country.join(mobile1[['Country Code', 'Series Name', 'Series Code',
       '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
       '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
       '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
       '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
       '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
       '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
       '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
       '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]']])
mobile1
# Out:
#               Country Name                 Region  ThirdWorld Country Code  \
# 0              Afghanistan             South Asia           1          AFG
# 1                  Albania         Eastern Europe           0          ALB
# 2                  Algeria                 Africa           0          DZA
# 3           American Samoa  Australia and Oceanea           0          ASM
# 4                  Andorra         Western Europe           0          AND
# ..                     ...                    ...         ...          ...
# 212  Virgin Islands (U.S.)          North America           0          VIR
# 213     West Bank and Gaza            Middle East           0          PSE
# 214            Yemen, Rep.            Middle East           1          YEM
# 215                 Zambia                 Africa           1          ZMB
# 216               Zimbabwe                 Africa           0          ZWE
#
#                                         Series Name     Series Code  \
# 0    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 1    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 2    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 3    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 4    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# ..                                              ...             ...
# 212  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 213  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 214  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 215  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 216  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
#
#      1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  ...  \
# 0         0.000000        0.00000       0.000000       0.000000  ...
# 1         0.000000        0.00000       0.000000       0.000000  ...
# 2         0.001825        0.01811       0.017689       0.017300  ...
# 3         0.000000        0.00000       1.402918       1.764014  ...
# 4         0.000000        0.00000       1.307567       1.279297  ...
# ..             ...            ...            ...            ...  ...
# 212       0.000000            NaN            NaN            NaN  ...
# 213       0.000000            NaN       0.000000       0.000000  ...
# 214       0.000000        0.00000       0.011965       0.037920  ...
# 215       0.000000        0.00000       0.000000       0.000000  ...
# 216       0.000000        0.00000       0.000000       0.000000  ...
#
#      2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# 0        45.813626      49.227977      52.083576      55.159515
# 1       105.852915     120.105858     126.936969     115.997935
# 2        97.148178     100.384679     103.610140     111.238610
# 3              NaN            NaN            NaN            NaN
# 4        77.667260      77.480680      79.147993      83.623900
# ..             ...            ...            ...            ...
# 212            NaN            NaN            NaN            NaN
# 213      69.523085      73.904186      73.617539      72.201640
# 214      49.009585      56.796874      66.984638      66.218793
# 215      58.221742      72.758845      69.646403      65.681859
# 216      71.349234      96.178351     102.118248      86.839674
#
#      2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 0        57.271068      61.054638      65.929134      59.120848
# 1       117.659218     116.744444     125.710352      94.176998
# 2       108.808940     116.004208     110.767246     111.664792
# 3              NaN            NaN            NaN            NaN
# 4        91.443514      98.492826     104.332411     107.282549
# ..             ...            ...            ...            ...
# 212            NaN            NaN            NaN            NaN
# 213      77.961373      80.100672      84.179796      89.975754
# 214      56.691131      60.486341      55.175024      53.678933
# 215      72.784572      73.438230      79.736910      89.157044
# 216      92.347105      91.793458      98.985073      89.404869
#
#      2019 [YR2019]  2020 [YR2020]
# 0        59.356020      58.255812
# 1        91.293015      91.002944
# 2       105.510594     103.887317
# 3              NaN            NaN
# 4       113.957377            NaN
# ..             ...            ...
# 212            NaN            NaN
# 213      86.325385      83.658511
# 214            NaN            NaN
# 215      96.414412     103.917835
# 216      90.102290      88.755806
#
# [217 rows x 37 columns]

# %%
mobile1 = mobile1[mobile1.Region != "Thailand"]
mobile1 = mobile1[mobile1.Region != "Australia and Oceanea"]

# %%
sns.heatmap(mobile1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
mobile1 = mobile1.dropna()
mobile1
# Out:
#       Country Name          Region  ThirdWorld Country Code  \
# 0      Afghanistan      South Asia           1          AFG
# 1          Albania  Eastern Europe           0          ALB
# 2          Algeria          Africa           0          DZA
# 5           Angola          Africa           1          AGO
# 7        Argentina   South America           0          ARG
# ..             ...             ...         ...          ...
# 208     Uzbekistan    Western Asia           0          UZB
# 210  Venezuela, RB   South America           0          VEN
# 211        Vietnam  Southeast Asia           0          VNM
# 215         Zambia          Africa           1          ZMB
# 216       Zimbabwe          Africa           0          ZWE
#
#                                         Series Name     Series Code  \
# 0    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 1    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 2    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 5    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 7    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# ..                                              ...             ...
# 208  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 210  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 211  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 215  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 216  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
#
#      1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  ...  \
# 0         0.000000       0.000000       0.000000       0.000000  ...
# 1         0.000000       0.000000       0.000000       0.000000  ...
# 2         0.001825       0.018110       0.017689       0.017300  ...
# 5         0.000000       0.000000       0.000000       0.008413  ...
# 7         0.036789       0.075577       0.138953       0.329702  ...
# ..             ...            ...            ...            ...  ...
# 208       0.000000       0.000000       0.000000       0.002287  ...
# 210       0.037804       0.082602       0.382144       0.868825  ...
# 211       0.000000       0.000000       0.001129       0.005615  ...
# 215       0.000000       0.000000       0.000000       0.000000  ...
# 216       0.000000       0.000000       0.000000       0.000000  ...
#
#      2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# 0        45.813626      49.227977      52.083576      55.159515
# 1       105.852915     120.105858     126.936969     115.997935
# 2        97.148178     100.384679     103.610140     111.238610
# 5        49.846773      50.920600      51.065920      52.158983
# 7       146.955455     154.059023     159.639461     143.615832
# ..             ...            ...            ...            ...
# 208      87.799911      68.843783      71.827966      71.119845
# 210      99.633497     104.115128     103.744124     101.614534
# 211     143.261020     146.626837     136.343827     148.448819
# 215      58.221742      72.758845      69.646403      65.681859
# 216      71.349234      96.178351     102.118248      86.839674
#
#      2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 0        57.271068      61.054638      65.929134      59.120848
# 1       117.659218     116.744444     125.710352      94.176998
# 2       108.808940     116.004208     110.767246     111.664792
# 5        49.793223      45.076290      44.686107      43.130519
# 7       143.566834     146.453828     140.877124     132.093151
# ..             ...            ...            ...            ...
# 208      70.428749      73.995208      75.924979      71.517371
# 210      96.714588      92.461416      83.304822      71.766138
# 211     129.831515     128.790785     126.866130     147.195273
# 215      72.784572      73.438230      79.736910      89.157044
# 216      92.347105      91.793458      98.985073      89.404869
#
#      2019 [YR2019]  2020 [YR2020]
# 0        59.356020      58.255812
# 1        91.293015      91.002944
# 2       105.510594     103.887317
# 5        46.598638      44.559511
# 7       125.842106     121.170400
# ..             ...            ...
# 208     101.207590      99.754392
# 210      64.792912      63.400007
# 211     141.226863     142.733362
# 215      96.414412     103.917835
# 216      90.102290      88.755806
#
# [133 rows x 37 columns]

# %%
sns.heatmap(mobile1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#mobile with outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=mobile1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_mobile2000_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(x="Region",y="2014 [YR2014]",data=mobile1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_mobile2014_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
#electricity without outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=mobile1, showfliers = False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_mobile2000_without_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(x="Region",y="2014 [YR2014]",data=mobile1, showfliers = False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_mobile2014_without_outliers.jpg', orientation="horizontal", dpi = 300)
