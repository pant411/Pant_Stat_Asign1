# %%
import os
os.chdir(os.getcwd())
os.getcwd()
# Out:
# '/Users/pantchanit/Documents/Pant_Stat_Asign1'

# %%
import pandas as pd
import numpy as np
import matplotlib as mpe
import seaborn as sns
# %matplotlib inline

# %%
country = pd.read_excel('countries_regions.xlsx')
country.head()
# Out:
#      Country Name                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %% [markdown]
# # GET DATA Broadband

# %%
broadband1 = pd.read_excel('infrastructure/broadband.xlsx')
broadband1.replace({'..':np.nan},inplace=True)
broadband1.head()
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND
#
#                                       Series Name     Series Code  \
# 0  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 1  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 2  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 3  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 4  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
#
#    1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  1994 [YR1994]  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    1995 [YR1995]  ...  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 0            NaN  ...            NaN       0.004814       0.004648
# 1            NaN  ...       4.377872       5.493573       6.286818
# 2            NaN  ...       2.675159       3.088892       3.356045
# 3            NaN  ...            NaN            NaN            NaN
# 4            NaN  ...      30.762893      32.641004      34.335306
#
#    2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  \
# 0       0.004495       0.020535       0.024874       0.025297       0.043041
# 1       7.180321       8.402315       9.228641      10.526845      12.555659
# 2       4.109816       5.712209       7.051711       7.756294       7.262935
# 3            NaN            NaN            NaN            NaN            NaN
# 4      36.319796      39.345733      42.032679      44.524097      46.311976
#
#    2019 [YR2019]  2020 [YR2020]
# 0       0.051741       0.068254
# 1      15.140735      17.684951
# 2       8.321684       8.643942
# 3            NaN            NaN
# 4      47.131264            NaN
#
# [5 rows x 35 columns]

# %%
broadband1.keys()
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
#        '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
#        '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
#        '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]'],
#       dtype='object')

# %%
broadband1 = country.join(broadband1[['2000 [YR2000]', '2014 [YR2014]']])
broadband1.head()
# Out:
#      Country Name                 Region  ThirdWorld  2000 [YR2000]  \
# 0     Afghanistan             South Asia           1            NaN
# 1         Albania         Eastern Europe           0            NaN
# 2         Algeria                 Africa           0            NaN
# 3  American Samoa  Australia and Oceanea           0            NaN
# 4         Andorra         Western Europe           0            NaN
#
#    2014 [YR2014]
# 0       0.004495
# 1       7.180321
# 2       4.109816
# 3            NaN
# 4      36.319796

# %%
broadband1 = broadband1[broadband1.Region != "Thailand"]
broadband1 = broadband1[broadband1.Region != "Australia and Oceanea"]

# %%
sns.heatmap(broadband1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
broadband1.groupby("Region")["2000 [YR2000]"].describe()
# Out:
#                  count      mean       std       min       25%       50%  \
# Region
# Africa             2.0  0.000380  0.000252  0.000202  0.000291  0.000380
# East Asia          5.0  3.287979  3.844977  0.001756  0.670191  0.872173
# Eastern Europe     2.0  0.016993  0.023014  0.000720  0.008856  0.016993
# Middle East        2.0  0.031611  0.044325  0.000268  0.015940  0.031611
# North America      5.0  1.453219  2.063312  0.013809  0.015167  0.114860
# Northern Europe    7.0  0.884696  0.948066  0.011912  0.303772  0.674640
# South America      6.0  0.025840  0.022980  0.002818  0.007678  0.020438
# South Asia         0.0       NaN       NaN       NaN       NaN       NaN
# Southeast Asia     2.0  0.857265  1.209681  0.001891  0.429578  0.857265
# Western Asia       0.0       NaN       NaN       NaN       NaN       NaN
# Western Europe    12.0  0.867672  0.880008  0.024297  0.233924  0.376910
#
#                       75%       max
# Region
# Africa           0.000468  0.000557
# East Asia        6.727642  8.168134
# Eastern Europe   0.025130  0.033266
# Middle East      0.047282  0.062953
# North America    2.509620  4.612640
# Northern Europe  1.047619  2.803536
# South America    0.043140  0.057211
# South Asia            NaN       NaN
# Southeast Asia   1.284952  1.712639
# Western Asia          NaN       NaN
# Western Europe   1.460077  2.488568

# %%
broadband1.groupby("Region")["2014 [YR2014]"].describe()
# Out:
#                  count       mean        std        min        25%        50%  \
# Region
# Africa            51.0   1.271442   2.783037   0.000678   0.074175   0.208457
# East Asia          6.0  24.632070  11.742064   6.708835  17.585075  28.423326
# Eastern Europe    16.0  18.812047   6.255791   7.180321  16.325074  18.119038
# Middle East       14.0  11.062596   9.336203   1.300481   4.057358   8.550669
# North America     30.0  15.743790  12.816778   0.000000   5.429007  14.345067
# Northern Europe   12.0  31.711736   6.621910  18.445930  27.150445  33.027526
# South America     12.0   9.784271   6.246241   1.613811   5.911358   8.329513
# South Asia         8.0   1.993413   1.509409   0.004495   1.004214   1.608740
# Southeast Asia     9.0   6.203629   8.499695   0.087539   0.432819   2.885195
# Western Asia       8.0   7.796800   7.481405   0.042076   2.040860   6.145258
# Western Europe    18.0  34.814510   6.672137  23.808273  27.920312  35.628517
#
#                        75%        max
# Region
# Africa            0.858152  14.474830
# East Asia        31.351813  37.936629
# Eastern Europe   22.240475  29.491978
# Middle East      16.523887  28.761629
# North America    21.745043  54.239220
# Northern Europe  36.306438  41.343184
# South America    12.370495  24.710390
# South Asia        2.916236   4.561222
# Southeast Asia    7.384404  26.675711
# Western Asia     13.033034  19.967867
# Western Europe   39.977433  47.693050

# %%
broadband1 = broadband1.dropna()
broadband1.head()
# Out:
#               Country Name          Region  ThirdWorld  2000 [YR2000]  \
# 11                 Austria  Western Europe           0       2.360807
# 18                 Belgium  Western Europe           0       1.402592
# 24  Bosnia and Herzegovina  Eastern Europe           0       0.000720
# 26                  Brazil   South America           0       0.057211
# 35                  Canada   North America           0       4.612640
#
#     2014 [YR2014]
# 11      27.381792
# 18      35.746533
# 24      15.576928
# 26      11.820828
# 35      35.239685

# %%
#broadband with outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=broadband1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_broadband2000_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(x="Region",y="2014 [YR2014]",data=broadband1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_broadband2014_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
#broadband without outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=broadband1, showfliers = False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_broadband2000_without_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(x="Region",y="2014 [YR2014]",data=broadband1, showfliers = False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_broadband2014_without_outliers.jpg', orientation="horizontal", dpi = 300)

# %% [markdown]
# # GET DATA Electricity

# %%
electricity1 = pd.read_excel('infrastructure/electricity.xlsx')
electricity1.replace({'..':np.nan},inplace=True)
electricity1.head()
# Out:
#      Country Name Country Code                                  Series Name  \
# 0     Afghanistan          AFG  Electric power consumption (kWh per capita)
# 1         Albania          ALB  Electric power consumption (kWh per capita)
# 2         Algeria          DZA  Electric power consumption (kWh per capita)
# 3  American Samoa          ASM  Electric power consumption (kWh per capita)
# 4         Andorra          AND  Electric power consumption (kWh per capita)
#
#          Series Code  1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  \
# 0  EG.USE.ELEC.KH.PC            NaN            NaN            NaN
# 1  EG.USE.ELEC.KH.PC     552.252185     418.453589     453.644074
# 2  EG.USE.ELEC.KH.PC     531.583836     532.490560     559.783013
# 3  EG.USE.ELEC.KH.PC            NaN            NaN            NaN
# 4  EG.USE.ELEC.KH.PC            NaN            NaN            NaN
#
#    1993 [YR1993]  1994 [YR1994]  1995 [YR1995]  ...  2011 [YR2011]  \
# 0            NaN            NaN            NaN  ...            NaN
# 1     536.363825     596.407959     663.783995  ...    2205.703920
# 2     547.990472     550.971960     559.917891  ...    1123.332915
# 3            NaN            NaN            NaN  ...            NaN
# 4            NaN            NaN            NaN  ...            NaN
#
#    2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1    2118.327776    2533.252829    2309.366503            NaN            NaN
# 2    1237.966109    1278.915242    1362.871884            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]
# 0            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN
#
# [5 rows x 35 columns]

# %%
electricity1.keys()
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
#        '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
#        '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
#        '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]'],
#       dtype='object')

# %%
electricity1 = country.join(electricity1[['2000 [YR2000]','2014 [YR2014]']])
electricity1.head()
# Out:
#      Country Name                 Region  ThirdWorld  2000 [YR2000]  \
# 0     Afghanistan             South Asia           1            NaN
# 1         Albania         Eastern Europe           0    1449.647413
# 2         Algeria                 Africa           0     683.294806
# 3  American Samoa  Australia and Oceanea           0            NaN
# 4         Andorra         Western Europe           0            NaN
#
#    2014 [YR2014]
# 0            NaN
# 1    2309.366503
# 2    1362.871884
# 3            NaN
# 4            NaN

# %%
electricity1 = electricity1[electricity1.Region != "Thailand"]
electricity1 = electricity1[electricity1.Region != "Australia and Oceanea"]

# %%
sns.heatmap(electricity1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
electricity1 = electricity1.dropna()
electricity1.head()
# Out:
#   Country Name          Region  ThirdWorld  2000 [YR2000]  2014 [YR2014]
# 1      Albania  Eastern Europe           0    1449.647413    2309.366503
# 2      Algeria          Africa           0     683.294806    1362.871884
# 5       Angola          Africa           1      75.264660     312.228895
# 7    Argentina   South America           0    2088.807630    3074.702071
# 8      Armenia    Western Asia           0    1297.564469    1961.610395

# %%
#electricity with outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=electricity1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_electricity2000_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(x="Region",y="2014 [YR2014]",data=electricity1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_electricity2014_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
#electricity without outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=electricity1, showfliers = False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_electricity2000_without_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(
    x="Region", y="2014 [YR2014]", data=electricity1, showfliers=False)
chart.set_xticklabels(chart.get_xticklabels(),
                      rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_electricity2014_without_outliers.jpg', orientation="horizontal", dpi = 300)

# %% [markdown]
# # GET DATA Mobile

# %%
mobile1 = pd.read_excel('infrastructure/mobile.xlsx')
mobile1.replace({'..':np.nan},inplace=True)
mobile1
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 217                                               NaN          NaN
# 218                                               NaN          NaN
# 219                                               NaN          NaN
# 220  Data from database: World Development Indicators          NaN
# 221                          Last Updated: 11/23/2021          NaN
#
#                                         Series Name     Series Code  \
# 0    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 1    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 2    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 3    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 4    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# ..                                              ...             ...
# 217                                             NaN             NaN
# 218                                             NaN             NaN
# 219                                             NaN             NaN
# 220                                             NaN             NaN
# 221                                             NaN             NaN
#
#      1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  \
# 0         0.000000        0.00000       0.000000       0.000000
# 1         0.000000        0.00000       0.000000       0.000000
# 2         0.001825        0.01811       0.017689       0.017300
# 3         0.000000        0.00000       1.402918       1.764014
# 4         0.000000        0.00000       1.307567       1.279297
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
#      1994 [YR1994]  1995 [YR1995]  ...  2011 [YR2011]  2012 [YR2012]  \
# 0         0.000000       0.000000  ...      45.813626      49.227977
# 1         0.000000       0.000000  ...     105.852915     120.105858
# 2         0.004778       0.016312  ...      97.148178     100.384679
# 3         2.303484       2.351348  ...            NaN            NaN
# 4         1.250858       4.424432  ...      77.667260      77.480680
# ..             ...            ...  ...            ...            ...
# 217            NaN            NaN  ...            NaN            NaN
# 218            NaN            NaN  ...            NaN            NaN
# 219            NaN            NaN  ...            NaN            NaN
# 220            NaN            NaN  ...            NaN            NaN
# 221            NaN            NaN  ...            NaN            NaN
#
#      2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0        52.083576      55.159515      57.271068      61.054638
# 1       126.936969     115.997935     117.659218     116.744444
# 2       103.610140     111.238610     108.808940     116.004208
# 3              NaN            NaN            NaN            NaN
# 4        79.147993      83.623900      91.443514      98.492826
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
#      2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]
# 0        65.929134      59.120848      59.356020      58.255812
# 1       125.710352      94.176998      91.293015      91.002944
# 2       110.767246     111.664792     105.510594     103.887317
# 3              NaN            NaN            NaN            NaN
# 4       104.332411     107.282549     113.957377            NaN
# ..             ...            ...            ...            ...
# 217            NaN            NaN            NaN            NaN
# 218            NaN            NaN            NaN            NaN
# 219            NaN            NaN            NaN            NaN
# 220            NaN            NaN            NaN            NaN
# 221            NaN            NaN            NaN            NaN
#
# [222 rows x 35 columns]

# %%
mobile1.keys()
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
#        '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
#        '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
#        '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]'],
#       dtype='object')

# %%
mobile1 = country.join(mobile1[['2000 [YR2000]',
       '2014 [YR2014]']])
mobile1.head()
# Out:
#      Country Name                 Region  ThirdWorld  2000 [YR2000]  \
# 0     Afghanistan             South Asia           1       0.000000
# 1         Albania         Eastern Europe           0       0.952019
# 2         Algeria                 Africa           0       0.277042
# 3  American Samoa  Australia and Oceanea           0       3.445115
# 4         Andorra         Western Europe           0      36.003976
#
#    2014 [YR2014]
# 0      55.159515
# 1     115.997935
# 2     111.238610
# 3            NaN
# 4      83.623900

# %%
mobile1 = mobile1[mobile1.Region != "Thailand"]
mobile1 = mobile1[mobile1.Region != "Australia and Oceanea"]

# %%
sns.heatmap(mobile1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
mobile1 = mobile1.dropna()
mobile1.head()
# Out:
#   Country Name          Region  ThirdWorld  2000 [YR2000]  2014 [YR2014]
# 0  Afghanistan      South Asia           1       0.000000      55.159515
# 1      Albania  Eastern Europe           0       0.952019     115.997935
# 2      Algeria          Africa           0       0.277042     111.238610
# 4      Andorra  Western Europe           0      36.003976      83.623900
# 5       Angola          Africa           1       0.157397      52.158983

# %%
sns.heatmap(mobile1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#mobile with outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=mobile1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_mobile2000_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(x="Region",y="2014 [YR2014]",data=mobile1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_mobile2014_with_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
#electricity without outliers

# %%
chart = sns.boxplot(x="Region",y="2000 [YR2000]",data=mobile1, showfliers = False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_mobile2000_without_outliers.jpg', orientation="horizontal", dpi = 300)

# %%
chart = sns.boxplot(x="Region",y="2014 [YR2014]",data=mobile1, showfliers = False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
fig = chart.get_figure()
fig.savefig('pic_boxplot_part1/boxplot_mobile2014_without_outliers.jpg', orientation="horizontal", dpi = 300)
